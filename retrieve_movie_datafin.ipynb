# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %%
type(tmdb_api_key)
# Out:
# str

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230331"

# Build URL
request_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    f"&fq={filter_query}&sort={sort}&fl={field_list}"
)

# %%
response_data = requests.get(request_url).json()

# %%
print(json.dumps(response_data, indent=4))
# Out:
# {
#     "status": "OK",
#     "copyright": "Copyright (c) 2024 The New York Times Company. All Rights Reserved.",
#     "response": {
#         "docs": [
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/30/movies/a-thousand-and-one-review.html",
#                 "snippet": "A mesmerizing Teyana Taylor stars in A.V. Rockwell\u2019s feature directing debut, about motherhood and survival in a fast-changing city.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018A Thousand and One\u2019 Review: A New York Love Story",
#                     "kicker": "Critic\u2019s Pick",
#                     "content_kicker": null,
#                     "print_headline": "An Unbending Will Meets a Shifting City",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "A Thousand and One (Movie)",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Rockwell, AV (Film Director)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Taylor, Teyana (1990- )",
#                         "rank": 4,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-30T18:53:42+0000",
#                 "byline": {
#                     "original": "By Manohla Dargis",
#                     "person": [
#                         {
#                             "firstname": "Manohla",
#                             "middlename": null,
#                             "lastname": "Dargis",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 971
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/02/09/movies/your-place-or-mine-review.html",
#                 "snippet": "This humdrum Netflix romantic comedy features Reese Witherspoon and Ashton Kutcher as longtime friends with possibly hidden feelings for each other.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018Your Place or Mine\u2019 Review: Try Neither",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "They Have a Humdrum Kind of Love",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Your Place or Mine (Movie)",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Witherspoon, Reese",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Kutcher, Ashton",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "McKenna, Aline Brosh",
#                         "rank": 5,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-02-10T00:00:05+0000",
#                 "byline": {
#                     "original": "By Amy Nicholson",
#                     "person": [
#                         {
#                             "firstname": "Amy",
#                             "middlename": null,
#                             "lastname": "Nicholson",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 569
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/02/02/movies/love-in-the-time-of-fentanyl-review.html",
#                 "snippet": "To combat the overdose crisis, a group that includes former and current users open a safe consumption site where shooting up does not have to mean death.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018Love in the Time of Fentanyl\u2019 Review: Heartbreak, Death and Hope in Vancouver",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Love in the Time Of Fentanyl",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Documentary Films and Programs",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Fentanyl",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Drug Abuse and Traffic",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Volunteers and Community Service",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Love in the Time of Fentanyl (Movie)",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Askey, Colin",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Vancouver (British Columbia)",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Overdose Prevention Society",
#                         "rank": 8,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-02-02T12:00:11+0000",
#                 "byline": {
#                     "original": "By Concepci\u00f3n de Le\u00f3n",
#                     "person": [
#                         {
#                             "firstname": "Concepci\u00f3n",
#                             "middlename": null,
#                             "lastname": "de Le\u00f3n",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 306
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/01/31/movies/pamela-a-love-story-review.html",
#                 "snippet": "This documentary from Ryan White rewinds, to powerful effect, on Pamela Anderson\u2019s life and fame.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018Pamela, a Love Story\u2019 Review: A Frank Look Back",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Pamela, a Love Story",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Documentary Films and Programs",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Anderson, Pamela (1967- )",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "White, Ryan (Filmmaker)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Pamela, a Love Story (Movie)",
#                         "rank": 4,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-01-31T12:00:05+0000",
#                 "byline": {
#                     "original": "By Glenn Kenny",
#                     "person": [
#                         {
#                             "firstname": "Glenn",
#                             "middlename": null,
#                             "lastname": "Kenny",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 295
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/01/19/movies/in-from-the-side-review.html",
#                 "snippet": "In Matt Carter\u2019s gay rugby film, sports and romance smash together like two players from opposing teams.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018In From the Side\u2019 Review: Love and Rugby Play a Losing Game",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "In From the Side",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "In From the Side (Movie)",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Carter, Matt (Filmmaker)",
#                         "rank": 3,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-01-19T17:50:16+0000",
#                 "byline": {
#                     "original": "By Kyle Turner",
#                     "person": [
#                         {
#                             "firstname": "Kyle",
#                             "middlename": null,
#                             "lastname": "Turner",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 281
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/01/19/movies/after-love-review.html",
#                 "snippet": "In this intelligent melodrama by the director Aleem Khan, a British woman discovers her husband has been leading a double life.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018After Love\u2019 Review: The Other Woman",
#                     "kicker": "Critic\u2019s Pick",
#                     "content_kicker": null,
#                     "print_headline": "After Love",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "After Love (2020) (Movie)",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Khan, Aleem",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Scanlan, Joanna (1961- )",
#                         "rank": 4,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-01-19T12:00:06+0000",
#                 "byline": {
#                     "original": "By Beatrice Loayza",
#                     "person": [
#                         {
#                             "firstname": "Beatrice",
#                             "middlename": null,
#                             "lastname": "Loayza",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 359
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/01/05/movies/alcarras-review.html",
#                 "snippet": "In this naturalistic drama from Spain, a family confronts the impending loss of its generations-old farm.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018Alcarr\u00e0s\u2019 Review: Labor of Love",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Alcarr\u00e0s",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Simon, Carla",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Alcarras (Movie)",
#                         "rank": 3,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-01-05T12:00:03+0000",
#                 "byline": {
#                     "original": "By Devika Girish",
#                     "person": [
#                         {
#                             "firstname": "Devika",
#                             "middlename": null,
#                             "lastname": "Girish",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 306
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2022/12/15/movies/nelly-and-nadine-review.html",
#                 "snippet": "A family archive provides intimate records of a love affair that began between two women imprisoned in the Ravensbr\u00fcck concentration camp.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018Nelly & Nadine\u2019 Review: An Unlikely Love, an Unlikely Record",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Nelly &amp; Nadine",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Documentary Films and Programs",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Gertten, Magnus",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Nelly & Nadine (Movie)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Content Type: Personal Profile",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Holocaust and the Nazi Era",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "World War II (1939-45)",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Women and Girls",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Homosexuality and Bisexuality",
#                         "rank": 8,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2022-12-15T12:00:04+0000",
#                 "byline": {
#                     "original": "By Teo Bugbee",
#                     "person": [
#                         {
#                             "firstname": "Teo",
#                             "middlename": null,
#                             "lastname": "Bugbee",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 308
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2022/12/01/movies/lady-chatterleys-lover-review.html",
#                 "snippet": "The new Netflix adaptation of D.H. Lawrence\u2019s once-controversial novel is both steamy and decorous.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018Lady Chatterley\u2019s Lover\u2019 Review: When Connie Met Ollie",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "A Love Whose Name Is Often Spoken",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Lady Chatterley's Lover (Movie)",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Corrin, Emma (1995- )",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "De Clermont-Tonnerre, Laure",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Lawrence, D H",
#                         "rank": 5,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2022-12-01T16:40:55+0000",
#                 "byline": {
#                     "original": "By A.O. Scott",
#                     "person": [
#                         {
#                             "firstname": "A.",
#                             "middlename": "O.",
#                             "lastname": "Scott",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 768
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2022/11/23/movies/sound-of-christmas-review.html",
#                 "snippet": "A young singer gets more than she bargained for when she accepts a job as a nanny for a billionaire\u2019s children.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "\u2018The Sound of Christmas\u2019 Review: A Gospel Singer Finds Love",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "The Sound  Of Christmas",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Movies",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Ne-Yo",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "The Sound of Christmas (Movie)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Mattison, Booker T",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "McNeill, Serayah",
#                         "rank": 5,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2022-11-23T15:00:09+0000",
#                 "byline": {
#                     "original": "By Concepci\u00f3n de Le\u00f3n",
#                     "person": [
#                         {
#                             "firstname": "Concepci\u00f3n",
#                             "middlename": null,
#                             "lastname": "de Le\u00f3n",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 277
#             }
#         ],
#         "meta": {
#             "hits": 337,
#             "offset": 0,
#             "time": 17
#         }
#     }
# }

# %%
# Create an empty list to store the reviews
review_list = []

# loop through pages 0-19
for page in range (20):
    try:
        request_url = (
            f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
            f"&fq={filter_query}&sort={sort}&fl={field_list}&page={page}"

    )
# create query with a page number

    try:
    
        response = requests.get(request_url)
        response_data = response.json()


        print("Response Data:", response_data)



    # API results show 10 articles at a time

    
    # Make a "GET" request and retrieve the JSON
        if "response" in response_data and "docs" in response_data["response"]:
            articles = response_data["response"]["docs"]
            review_list.extend(articles)
            if articles:
                print(f"Retrieved {len(articles)} articles for page {page}")
            

            else:
                print(f"no reuslts for page {page}")

        else:
            print(f"No results for page {page}")
    
    # Add a twelve second interval between queries to stay within API query limits
        time.sleep(12)
    
    except Exception as e:

        print(f"Error occurred while fetching data for page {page}: {e}")
    

print(f"Total articles retrieved: {len(review_list)}")
    # Try and save the reviews to the reviews_list

        # loop through _the reviews["response"]["docs"] and append each review to the list
# Out:
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/interactive/2023/03/31/sports/ncaabasketball/locker-room-celebrations-water-pour.html', 'snippet': 'Hold the champagne. Water has become the go-to beverage for celebrating success in sports.', 'source': 'The New York Times', 'headline': {'main': 'When Every Win Means Water, Water Everywhere', 'kicker': None, 'content_kicker': None, 'print_headline': 'You’d Better Not Try This in Your Workplace!', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Water', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Athletics and Sports', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Basketball (College)', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'NCAA Basketball Championships (Men)', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'NCAA Basketball Championships (Women)', 'rank': 5, 'major': 'N'}], 'pub_date': '2023-03-31T22:51:36+0000', 'byline': {'original': 'By Andrew Keh', 'person': [{'firstname': 'Andrew', 'middlename': None, 'lastname': 'Keh', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 0}, {'web_url': 'https://www.nytimes.com/2023/03/31/us/minneapolis-police-reform-agreement.html', 'snippet': 'A deal with state human-rights officials calls for the city’s police to rein in the use of force and cease practices that critics say have been racially discriminatory.', 'source': 'The New York Times', 'headline': {'main': 'Minneapolis Agrees to Sweeping Changes in Policing', 'kicker': None, 'content_kicker': None, 'print_headline': 'Minneapolis Agrees to Make Major Changes in Policing', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'glocations', 'value': 'Minneapolis (Minn)', 'rank': 1, 'major': 'N'}, {'name': 'organizations', 'value': 'Police Department (Minneapolis, Minn)', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Police Reform', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Black People', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Blacks', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Discrimination', 'rank': 6, 'major': 'N'}, {'name': 'subject', 'value': 'Search and Seizure', 'rank': 7, 'major': 'N'}, {'name': 'subject', 'value': 'Racial Profiling', 'rank': 8, 'major': 'N'}], 'pub_date': '2023-03-31T22:29:30+0000', 'byline': {'original': 'By Ernesto Londoño', 'person': [{'firstname': 'Ernesto', 'middlename': None, 'lastname': 'Londoño', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 948}, {'web_url': 'https://www.nytimes.com/2023/03/31/briefing/donald-trump-arraignment-russia-recruitment.html', 'snippet': 'Here’s what you need to know at the end of the day.', 'source': 'The New York Times', 'headline': {'main': 'Your Friday Evening Briefing', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [], 'pub_date': '2023-03-31T21:30:24+0000', 'byline': {'original': 'By Matthew Cullen', 'person': [{'firstname': 'Matthew', 'middlename': None, 'lastname': 'Cullen', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1322}, {'web_url': 'https://www.nytimes.com/2023/03/31/technology/sam-altman-open-ai-chatgpt.html', 'snippet': 'Sam Altman sees the pros and cons of totally changing the world as we know it. And if he does make human intelligence useless, he has a plan to fix it.', 'source': 'The New York Times', 'headline': {'main': 'The ChatGPT King Isn’t Worried, but He Knows You Might Be', 'kicker': None, 'content_kicker': None, 'print_headline': 'He’s Not  Worried,  But He  Knows  You Are', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': ' ...
# Retrieved 10 articles for page 0
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/31/realestate/scotland-golf-archerfield-house.html', 'snippet': 'Since the late 17th century, when Archerfield House was built, the East Lothian area has been a desired locale to lay roots and swing iron.', 'source': 'International New York Times', 'headline': {'main': 'In Scotland, Coastal Living Beckons at a Golfing Hot Spot', 'kicker': None, 'content_kicker': None, 'print_headline': 'Coastal life beckons in Scotland', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Golf', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Real Estate and Housing (Residential)', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Historic Buildings and Sites', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'ARCHITECTURE', 'rank': 4, 'major': 'N'}, {'name': 'glocations', 'value': 'East Lothian (Scotland)', 'rank': 6, 'major': 'N'}, {'name': 'glocations', 'value': 'Scotland', 'rank': 7, 'major': 'N'}], 'pub_date': '2023-03-31T09:03:03+0000', 'byline': {'original': 'By Rachel Chaundler', 'person': [{'firstname': 'Rachel', 'middlename': None, 'lastname': 'Chaundler', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1284}, {'web_url': 'https://www.nytimes.com/2023/03/31/realestate/design-golf-homes.html', 'snippet': 'Living in Augusta, Ga., the interior designer Lauren Robbins has a firsthand perspective on the importance of the aesthetic and feel in golf communities.', 'source': 'International New York Times', 'headline': {'main': 'Focusing on the Design Inside of Golf Homes', 'kicker': None, 'content_kicker': None, 'print_headline': 'Focusing on the design inside the house', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Golf', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Interior Design and Furnishings', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Real Estate and Housing (Residential)', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Luxury Goods and Services', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Renting and Leasing (Real Estate)', 'rank': 5, 'major': 'N'}, {'name': 'glocations', 'value': 'Augusta (Ga)', 'rank': 6, 'major': 'N'}], 'pub_date': '2023-03-31T09:00:33+0000', 'byline': {'original': 'By Shivani Vora', 'person': [{'firstname': 'Shivani', 'middlename': None, 'lastname': 'Vora', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 954}, {'web_url': 'https://www.nytimes.com/2023/03/31/realestate/first-time-home-buyer-retirement.html', 'snippet': 'Many older home buyers say ownership was worth the wait, as they finally make a major real estate investment and consider their financial legacy.', 'source': 'The New York Times', 'headline': {'main': 'Retired and Buying a Starter Home. It’s Forever.', 'kicker': None, 'content_kicker': None, 'print_headline': 'A Starter Home Later in Life', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Real Estate and Housing (Residential)', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Personal Finances', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Retirement', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Mortgages', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Age, Chronological', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Renting and Leasing (Real Estate)', 'rank': 6, 'major': 'N'}, {'name': 'glocations', 'value': 'United States', 'rank': 9, 'major': 'N'}], 'pub_date': '2023-03-31T09:00:28+0000', 'byline': {'original': 'By Debra Kamin', 'person': [{'firstname': 'Debra', 'middlename': None, 'lastname': 'Kamin', 'qualifier': None, 'title': None, 'role': 're ...
# Retrieved 10 articles for page 1
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/30/us/las-vegas-shooting-gunman.html', 'snippet': 'While investigators concluded that the motive of Stephen Paddock was unclear, newly released records include an account that he was angry about the casinos’ treatment of wealthy clients.', 'source': 'The New York Times', 'headline': {'main': 'Gunman in 2017 Las Vegas Shooting Was Angry at Casinos, New F.B.I. Files Show', 'kicker': None, 'content_kicker': None, 'print_headline': 'Gambler Who Killed 60 Was Angry at Treatment By Casinos, F.B.I. Reveals', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Las Vegas, Nev, Shooting (October, 2017)', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Paddock, Stephen C (1953-2017)', 'rank': 2, 'major': 'N'}, {'name': 'glocations', 'value': 'Las Vegas (Nev)', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Casinos', 'rank': 4, 'major': 'N'}], 'pub_date': '2023-03-30T23:40:52+0000', 'byline': {'original': 'By Serge F. Kovaleski and Mike Baker', 'person': [{'firstname': 'Serge', 'middlename': 'F.', 'lastname': 'Kovaleski', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}, {'firstname': 'Mike', 'middlename': None, 'lastname': 'Baker', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 2}], 'organization': None}, 'word_count': 877}, {'web_url': 'https://www.nytimes.com/2023/03/30/books/review/9-new-books-we-recommend-this-week.html', 'snippet': 'Suggested reading from critics and editors at The New York Times.', 'source': 'The New York Times', 'headline': {'main': '9 New Books We Recommend This Week', 'kicker': 'Editors’ choice', 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Books and Literature', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Content Type: Service', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': "We Are Electric: Inside the 200-Year Hunt for Our Body's Bioelectric Code, and What the Future Holds (Book)", 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Adee, Sally', 'rank': 4, 'major': 'N'}, {'name': 'creative_works', 'value': 'Take What You Need (Book)', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Novey, Idra', 'rank': 6, 'major': 'N'}, {'name': 'persons', 'value': 'Atwood, Margaret', 'rank': 7, 'major': 'N'}, {'name': 'persons', 'value': 'Schine, Cathleen', 'rank': 8, 'major': 'N'}, {'name': 'persons', 'value': 'Waidner, Isabel', 'rank': 9, 'major': 'N'}, {'name': 'creative_works', 'value': 'Thirst for Salt (Book)', 'rank': 10, 'major': 'N'}, {'name': 'persons', 'value': 'Lucas, Madelaine', 'rank': 11, 'major': 'N'}, {'name': 'creative_works', 'value': 'Francisco (Book)', 'rank': 12, 'major': 'N'}, {'name': 'persons', 'value': 'Mills Newman, Alison', 'rank': 13, 'major': 'N'}, {'name': 'persons', 'value': 'Brendborg, Nicklas', 'rank': 14, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Half Known Life: In Search of Paradise (Book)', 'rank': 15, 'major': 'N'}, {'name': 'persons', 'value': 'Iyer, Pico', 'rank': 16, 'major': 'N'}], 'pub_date': '2023-03-30T17:56:41+0000', 'byline': {'original': None, 'person': [], 'organization': None}, 'word_count': 643}, {'web_url': 'https://www.nytimes.com/2023/03/30/us/politics/biden-irs-overhaul-taxes.html', 'snippet': 'The tax preparation industry is alarmed over the prospect that the Internal Revenue Service will devise its own free tax-filing system.', 'source': 'The New York Times', 'headline': {'main': 'Lobbyists Begin Chipping Away at Biden’s $80 Billion I.R.S. Overhaul', 'kicker': None, 'content_kicker': None, 'print_headline': 'Tax Prep Industry Fights White House Plan for Free Digital Tax Filing', 'name': None, 'seo': None, 'sub': None}, 'keywords': [ ...
# Retrieved 10 articles for page 2
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/30/movies/kill-boksoon-review.html', 'snippet': 'An assassin must choose between the murderous career she loves and the daughter she’s been hiding it from.', 'source': 'The New York Times', 'headline': {'main': '‘Kill Boksoon’ Review: It’s a Deadly Job for a Busy Single Mom', 'kicker': 'Critic’s Pick', 'content_kicker': None, 'print_headline': 'Kill Boksoon', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Kill Boksoon (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Byun Sung-hyun', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Jeon Do-yeon', 'rank': 4, 'major': 'N'}], 'pub_date': '2023-03-30T11:00:07+0000', 'byline': {'original': 'By Robert Daniels', 'person': [{'firstname': 'Robert', 'middlename': None, 'lastname': 'Daniels', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 274}, {'web_url': 'https://www.nytimes.com/2023/03/30/world/europe/ukraine-satellite-darkness.html', 'snippet': 'A satellite operated by NASA and NOAA bares how Russia’s drones and missiles knocked out the nation’s power.', 'source': 'The New York Times', 'headline': {'main': 'Ukraine Goes Dark: Images From Space Drive Home the Nation’s Anguish', 'kicker': None, 'content_kicker': None, 'print_headline': 'From Space, Darkness Underscores Ukraine’s Misery', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Russian Invasion of Ukraine (2022)', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Satellites', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Power Failures and Blackouts', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Electric Light and Power', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Infrastructure (Public Works)', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Defense and Military Forces', 'rank': 6, 'major': 'N'}, {'name': 'organizations', 'value': 'National Aeronautics and Space Administration', 'rank': 7, 'major': 'N'}, {'name': 'organizations', 'value': 'National Oceanic and Atmospheric Administration', 'rank': 8, 'major': 'N'}, {'name': 'glocations', 'value': 'Ukraine', 'rank': 9, 'major': 'N'}, {'name': 'glocations', 'value': 'Russia', 'rank': 10, 'major': 'N'}, {'name': 'glocations', 'value': 'Kyiv (Ukraine)', 'rank': 11, 'major': 'N'}, {'name': 'glocations', 'value': 'Odessa (Ukraine)', 'rank': 12, 'major': 'N'}, {'name': 'glocations', 'value': 'Mariupol (Ukraine)', 'rank': 13, 'major': 'N'}, {'name': 'subject', 'value': 'vis-video', 'rank': 14, 'major': 'N'}], 'pub_date': '2023-03-30T09:00:29+0000', 'byline': {'original': 'By William J. Broad, Sarah Kerr, Marc Santora and Tim Wallace', 'person': [{'firstname': 'William', 'middlename': 'J.', 'lastname': 'Broad', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}, {'firstname': 'Sarah', 'middlename': None, 'lastname': 'Kerr', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 2}, {'firstname': 'Marc', 'middlename': None, 'lastname': 'Santora', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 3}, {'firstname': 'Tim', 'middlename': None, 'lastname': 'Wallace', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 4}], 'organization': None}, 'word_count': 1726}, {'web_url': 'https://www.nytimes.com/2023/03/30/business/media/publishers-chatbots-search-engines.html', 'snippet': 'Many sites get at least half their traffic from search engines. Fuller results generated by new chatbots could mean far fewer visitors.', 'source': 'The New York Times', 'headline': {'main': 'Publishers Worry A.I. Chatbots Will C ...
# Retrieved 10 articles for page 3
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/29/nyregion/nyc-suburbs-homes-hochul.html', 'snippet': 'The governor’s quest, to force suburbs around New York City to build more housing, is meeting with resistance.', 'source': 'The New York Times', 'headline': {'main': 'Can New York Fix Its Housing Crisis? It Depends on the Suburbs', 'kicker': None, 'content_kicker': None, 'print_headline': 'Hochul Seeks Help From Suburbs to Fix New York’s Housing Crisis', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'glocations', 'value': 'New York Metropolitan Area', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Area Planning and Renewal', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Real Estate and Housing (Residential)', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Suburbs', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Affordable Housing', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Parking Garages and Lots', 'rank': 6, 'major': 'N'}, {'name': 'persons', 'value': 'Hochul, Kathleen C', 'rank': 7, 'major': 'N'}, {'name': 'glocations', 'value': 'Scarsdale (NY)', 'rank': 8, 'major': 'N'}, {'name': 'glocations', 'value': 'New York State', 'rank': 9, 'major': 'N'}, {'name': 'subject', 'value': 'Budgets and Budgeting', 'rank': 10, 'major': 'N'}], 'pub_date': '2023-03-29T14:21:46+0000', 'byline': {'original': 'By Mihir Zaveri, Luis Ferré-Sadurní and Michael D. Regan', 'person': [{'firstname': 'Mihir', 'middlename': None, 'lastname': 'Zaveri', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}, {'firstname': 'Luis', 'middlename': None, 'lastname': 'Ferré-Sadurní', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 2}, {'firstname': 'Michael', 'middlename': None, 'lastname': None, 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 3}], 'organization': None}, 'word_count': 1490}, {'web_url': 'https://www.nytimes.com/2023/03/29/realestate/wallkill-ny-homes-hudson-valley.html', 'snippet': 'This Ulster County hamlet may not be as fashionable as some Hudson Valley towns, but it’s more affordable. And everyone turns out for the spring Duck Derby.', 'source': 'The New York Times', 'headline': {'main': 'Wallkill, N.Y.: An Escape From ‘Hip and Trendy’', 'kicker': 'Living in', 'content_kicker': None, 'print_headline': 'This Pastoral Hamlet Is Cheerfully Unhip', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Real Estate and Housing (Residential)', 'rank': 1, 'major': 'N'}, {'name': 'glocations', 'value': 'Wallkill (Ulster County, NY)', 'rank': 2, 'major': 'N'}], 'pub_date': '2023-03-29T13:05:28+0000', 'byline': {'original': 'By Karen Angel', 'person': [{'firstname': 'Karen', 'middlename': None, 'lastname': 'Angel', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1776}, {'web_url': 'https://www.nytimes.com/2023/03/29/technology/personaltech/ai-chatgpt-google-bard-assistant.html', 'snippet': 'Google’s Bard chatbot fared far worse than OpenAI’s ChatGPT, but human assistants might soon be out of their jobs.', 'source': 'The New York Times', 'headline': {'main': 'How ChatGPT and Bard Performed as My Executive Assistants', 'kicker': 'Tech Fix', 'content_kicker': None, 'print_headline': 'In Battle of the Bots, Human Assistants Are the Real Losers', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Computers and the Internet', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Artificial Intelligence', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'ChatGPT', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Tests and Examinations', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Start-ups', 'rank': ...
# Retrieved 10 articles for page 4
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/29/opinion/how-to-accept-death.html', 'snippet': 'It is easier to search for readiness than to process what its absence means.', 'source': 'The New York Times', 'headline': {'main': 'As a Doctor, I Know Being Ready to Die Is an Illusion', 'kicker': 'Guest Essay', 'content_kicker': None, 'print_headline': 'As a Doctor, I Know Being Ready to Die Is an Illusion', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Death and Dying', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Grief (Emotion)', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Doctors', 'rank': 3, 'major': 'N'}], 'pub_date': '2023-03-29T09:00:15+0000', 'byline': {'original': 'By Sunita Puri', 'person': [{'firstname': 'Sunita', 'middlename': None, 'lastname': 'Puri', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1325}, {'web_url': 'https://www.nytimes.com/2023/03/29/travel/adult-resorts-family-kids.html', 'snippet': 'Parents fed up with being cooped up have driven a pandemic surge in family trips, and properties from Mexico to the Poconos are getting makeovers to meet the demand.', 'source': 'The New York Times', 'headline': {'main': 'Go On, Take the Kids to Mykonos: Adult Resorts Open Up to Families', 'kicker': None, 'content_kicker': None, 'print_headline': 'Go Ahead,  Take the Kids  With You  To Mykonos', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Travel and Vacations', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Children and Childhood', 'rank': 2, 'major': 'N'}, {'name': 'glocations', 'value': 'Mykonos (Greece)', 'rank': 3, 'major': 'N'}, {'name': 'glocations', 'value': 'Puerto Vallarta (Mexico)', 'rank': 4, 'major': 'N'}, {'name': 'glocations', 'value': 'Grand Cayman (Cayman Islands)', 'rank': 5, 'major': 'N'}, {'name': 'glocations', 'value': 'Brooklyn (NYC)', 'rank': 6, 'major': 'N'}, {'name': 'glocations', 'value': 'Cape Cod (Mass)', 'rank': 7, 'major': 'N'}, {'name': 'glocations', 'value': 'Connecticut', 'rank': 8, 'major': 'N'}, {'name': 'glocations', 'value': 'Lake Como (Italy)', 'rank': 9, 'major': 'N'}], 'pub_date': '2023-03-29T09:00:14+0000', 'byline': {'original': 'By Debra Kamin', 'person': [{'firstname': 'Debra', 'middlename': None, 'lastname': 'Kamin', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1412}, {'web_url': 'https://www.nytimes.com/2023/03/28/us/politics/biden-economy.html', 'snippet': 'The president has warned that a strong economy could be weakened under Republican leadership, a point he and a host of advisers will make at 20 events across the country in the coming weeks.', 'source': 'The New York Times', 'headline': {'main': 'Biden Highlights Economic Investments Ahead of Expected 2024 Announcement', 'kicker': None, 'content_kicker': None, 'print_headline': 'Biden Puts Spotlight On Economic Package Ahead of 2024 Race', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Factories and Manufacturing', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'United States Politics and Government', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'United States Economy', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Presidential Election of 2024', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Supply Chain', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Computer Chips', 'rank': 6, 'major': 'N'}, {'name': 'subject', 'value': 'National Debt (US)', 'rank': 7, 'major': 'N'}, {'name': 'persons', 'value': 'Biden, Joseph R Jr', 'rank': 8, 'major': 'N'}], 'pub_date': '2023-03-28T22:44:34+0000', 'byline': {'original': 'By Katie Rogers', 'person': [{'fi ...
# Retrieved 10 articles for page 5
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/28/style/big-shoulders-trend.html', 'snippet': 'The Great Shoulder Resurgence of 2023 is coming. Here’s why.', 'source': 'The New York Times', 'headline': {'main': 'How Wide Can You Go?', 'kicker': None, 'content_kicker': None, 'print_headline': 'The Great Shoulder Resurgence of 2023', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Fashion and Apparel', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Women and Girls', 'rank': 2, 'major': 'N'}, {'name': 'organizations', 'value': 'Yves Saint Laurent', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'your-feed-fashion', 'rank': 4, 'major': 'N'}], 'pub_date': '2023-03-28T09:00:24+0000', 'byline': {'original': 'By Vanessa Friedman', 'person': [{'firstname': 'Vanessa', 'middlename': None, 'lastname': 'Friedman', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1528}, {'web_url': 'https://www.nytimes.com/2023/03/28/magazine/quarantine-hotel-vacation.html', 'snippet': '138 hours in solitude turned out to be just the vacation this writer needed.', 'source': 'The New York Times', 'headline': {'main': 'The Unexpected Joys of a Quarantine Hotel', 'kicker': 'Letter of Recommendation', 'content_kicker': None, 'print_headline': 'Staycations', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Quarantines', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Coronavirus (2019-nCoV)', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Hotels and Travel Lodgings', 'rank': 3, 'major': 'N'}, {'name': 'glocations', 'value': 'Osaka (Japan)', 'rank': 4, 'major': 'N'}], 'pub_date': '2023-03-28T09:00:23+0000', 'byline': {'original': 'By Pico Iyer', 'person': [{'firstname': 'Pico', 'middlename': None, 'lastname': 'Iyer', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 890}, {'web_url': 'https://www.nytimes.com/2023/03/27/technology/lyft-founders-resign.html', 'snippet': 'Lyft has been slow to bounce back from early pandemic problems even as the business of its much bigger rival, Uber, has improved.', 'source': 'The New York Times', 'headline': {'main': 'Lyft’s Co-Founders to Step Down as Company Struggles', 'kicker': None, 'content_kicker': None, 'print_headline': 'Founders of Lyft Will Step Down Amid Layoffs and Disappointing Bottom Line', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Computers and the Internet', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Car Services and Livery Cabs', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Appointments and Executive Changes', 'rank': 3, 'major': 'N'}, {'name': 'organizations', 'value': 'Lyft Inc', 'rank': 4, 'major': 'N'}, {'name': 'organizations', 'value': 'Uber Technologies Inc', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Green, Logan', 'rank': 6, 'major': 'N'}, {'name': 'persons', 'value': 'Zimmer, John (1984- )', 'rank': 7, 'major': 'N'}], 'pub_date': '2023-03-27T21:09:05+0000', 'byline': {'original': 'By Kellen Browning', 'person': [{'firstname': 'Kellen', 'middlename': None, 'lastname': 'Browning', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 832}, {'web_url': 'https://www.nytimes.com/2023/03/27/opinion/ai-chatgpt-chatbots.html', 'snippet': 'Silicon Valley’s futurists have gone from utopian to dystopian.', 'source': 'The New York Times', 'headline': {'main': 'A.I. Is Being Built by People Who Think It Might Destroy Us', 'kicker': 'David wallace-wells', 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'in ...
# Retrieved 10 articles for page 6
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/26/us/violent-storms-leave-behind-scenes-of-devastation-and-heartbreak.html', 'snippet': 'Photographers on the ground captured scenes of storm’s aftermath.', 'source': 'The New York Times', 'headline': {'main': 'In pictures: Violent storms leave behind scenes of devastation and heartbreak.', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [], 'pub_date': '2023-03-26T17:32:19+0000', 'byline': {'original': 'By The New York Times', 'person': [], 'organization': 'The New York Times'}, 'word_count': 325}, {'web_url': 'https://www.nytimes.com/2023/03/26/technology/apple-augmented-reality-dissent.html', 'snippet': 'The company is expected to unveil an augmented reality headset in a few months. Some employees wonder if the device makes sense for Apple.', 'source': 'The New York Times', 'headline': {'main': 'At Apple, Rare Dissent Over a New Product: Interactive Goggles', 'kicker': None, 'content_kicker': None, 'print_headline': 'Apple’s Newest Product Is Nearly Here. Some Employees Are Far From Excited.', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Computers and the Internet', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Wearable Computing', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Augmented Reality (Computers)', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Headphones and Headsets', 'rank': 4, 'major': 'N'}, {'name': 'organizations', 'value': 'Apple Inc', 'rank': 5, 'major': 'N'}, {'name': 'organizations', 'value': 'Meta Platforms Inc', 'rank': 6, 'major': 'N'}, {'name': 'persons', 'value': 'Cook, Timothy D', 'rank': 7, 'major': 'N'}, {'name': 'persons', 'value': 'Ive, Jonathan', 'rank': 8, 'major': 'N'}], 'pub_date': '2023-03-26T14:11:41+0000', 'byline': {'original': 'By Tripp Mickle and Brian X. Chen', 'person': [{'firstname': 'Tripp', 'middlename': None, 'lastname': 'Mickle', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}, {'firstname': 'Brian', 'middlename': 'X.', 'lastname': 'Chen', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 2}], 'organization': None}, 'word_count': 1293}, {'web_url': 'https://www.nytimes.com/2023/03/26/briefing/turkey-earthquake.html', 'snippet': 'Documenting the damage of last month’s earthquakes in Turkey.', 'source': 'The New York Times', 'headline': {'main': 'History in the Rubble', 'kicker': None, 'content_kicker': None, 'print_headline': 'In the Ruin and Rubble, Documenting History', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Turkey Earthquake (Feb 6, 2023)', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Buildings (Structures)', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Accidents and Safety', 'rank': 3, 'major': 'N'}], 'pub_date': '2023-03-26T11:05:00+0000', 'byline': {'original': 'By Ashley Wu', 'person': [{'firstname': 'Ashley', 'middlename': None, 'lastname': 'Wu', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1389}, {'web_url': 'https://www.nytimes.com/2023/03/26/business/the-week-in-business-tiktok-in-the-hot-seat.html', 'snippet': 'The Fed raised interest rates, even as some banks continued to find themselves on shaky ground. The A.I. race is on. And a new inflation reading is coming.', 'source': 'The New York Times', 'headline': {'main': 'The Week in Business: TikTok in the Hot Seat', 'kicker': 'with interest', 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'organizations', 'value': 'TikTok (ByteDance)', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'United States Economy', 'rank': 2, 'maj ...
# Retrieved 10 articles for page 7
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/25/us/tornado-mississippi-storms-dead.html', 'snippet': 'Dozens more were injured after a deadly tornado ripped through a rural area. The death toll is expected to rise.', 'source': 'The New York Times', 'headline': {'main': 'At Least 26 Killed as Powerful Tornado Tears Through Mississippi', 'kicker': None, 'content_kicker': None, 'print_headline': 'At Least 24 Die as Tornadoes Wreck Rural South', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Tornadoes', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Deaths (Fatalities)', 'rank': 2, 'major': 'N'}, {'name': 'glocations', 'value': 'Mississippi', 'rank': 3, 'major': 'N'}, {'name': 'glocations', 'value': 'Alabama', 'rank': 4, 'major': 'N'}, {'name': 'glocations', 'value': 'Rolling Fork (Miss)', 'rank': 5, 'major': 'N'}, {'name': 'glocations', 'value': 'Silver City (Miss)', 'rank': 6, 'major': 'N'}], 'pub_date': '2023-03-25T10:51:47+0000', 'byline': {'original': 'By Rick Rojas, Sarah Kramer Ozbun, Emily Cochrane and Richard Fausset', 'person': [{'firstname': 'Rick', 'middlename': None, 'lastname': 'Rojas', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}, {'firstname': 'Sarah', 'middlename': 'Kramer', 'lastname': 'Ozbun', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 2}, {'firstname': 'Emily', 'middlename': None, 'lastname': 'Cochrane', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 3}, {'firstname': 'Richard', 'middlename': None, 'lastname': 'Fausset', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 4}], 'organization': None}, 'word_count': 1698}, {'web_url': 'https://www.nytimes.com/2023/03/24/us/fire-chocolate-factory-west-reading.html', 'snippet': 'One person was found alive in the rubble overnight on Friday after an explosion at the R.M. Palmer Company chocolate factory in West Reading, Pa., officials said.', 'source': 'The New York Times', 'headline': {'main': 'Death Toll Rises to 7 in Chocolate Factory Explosion', 'kicker': None, 'content_kicker': None, 'print_headline': 'Explosion at Pennsylvania Chocolate Factory Leaves at Least Two Dead and Five Missing', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'organizations', 'value': 'RM Palmer Co', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Explosions (Accidental)', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Fires and Firefighters', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Factories and Manufacturing', 'rank': 4, 'major': 'N'}, {'name': 'glocations', 'value': 'West Reading (Pa)', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'internal-storyline-no', 'rank': 6, 'major': 'N'}, {'name': 'subject', 'value': 'Deaths (Fatalities)', 'rank': 7, 'major': 'N'}], 'pub_date': '2023-03-25T00:41:58+0000', 'byline': {'original': 'By David DeKok, Amanda Holpuch and Michael Levenson', 'person': [{'firstname': 'David', 'middlename': None, 'lastname': 'DeKok', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}, {'firstname': 'Amanda', 'middlename': None, 'lastname': 'Holpuch', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 2}, {'firstname': 'Michael', 'middlename': None, 'lastname': 'Levenson', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 3}], 'organization': None}, 'word_count': 813}, {'web_url': 'https://www.nytimes.com/2023/03/24/us/politics/trump-mark-meadows-executive-privilege-jan-6.html', 'snippet': 'The ruling paves the way for testimony from Mark Meadows and others. Separately, a Trump lawyer appeared before a grand jury looking into the former president’s handling of classified documents.', 'source': 'Th ...
# Retrieved 10 articles for page 8
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/24/us/politics/donald-trump-waco-branch-davidians.html', 'snippet': 'Thirty years ago, a fiery federal raid on a doomsday sect turned the city into a symbol of government overreach. Donald Trump will speak there on Saturday, and some supporters — and critics — say it’s no accident.', 'source': 'The New York Times', 'headline': {'main': 'A Trump Rally, a Right-Wing Cause and the Enduring Legacy of Waco', 'kicker': None, 'content_kicker': None, 'print_headline': '‘Touchstone’ for Far Right Turns Campaign Stop', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Presidential Election of 2024', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Right-Wing Extremism and Alt-Right', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'United States Politics and Government', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Religious Cults', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Conspiracy Theories', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Trump, Donald J', 'rank': 6, 'major': 'N'}, {'name': 'organizations', 'value': 'Republican Party', 'rank': 7, 'major': 'N'}, {'name': 'glocations', 'value': 'Waco (Tex)', 'rank': 8, 'major': 'N'}, {'name': 'persons', 'value': 'Koresh, David', 'rank': 9, 'major': 'N'}, {'name': 'organizations', 'value': 'Branch Davidians', 'rank': 10, 'major': 'N'}], 'pub_date': '2023-03-24T09:00:33+0000', 'byline': {'original': 'By Charles Homans', 'person': [{'firstname': 'Charles', 'middlename': None, 'lastname': 'Homans', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1576}, {'web_url': 'https://www.nytimes.com/2023/03/24/realestate/mushroom-home-decor.html', 'snippet': 'As mushrooms become more prominent in nearly all spheres of modern life — including wellness, pop culture and cuisine — they’re also becoming sought-after motifs in interior design.', 'source': 'The New York Times', 'headline': {'main': 'These Mushrooms Are Not for Eating', 'kicker': None, 'content_kicker': None, 'print_headline': 'Mushroom Mania', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Interior Design and Furnishings', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Mushrooms', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Furniture', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Lamps and Lampshades', 'rank': 4, 'major': 'N'}, {'name': 'glocations', 'value': 'United States', 'rank': 5, 'major': 'N'}], 'pub_date': '2023-03-24T09:00:29+0000', 'byline': {'original': 'By Anna Kodé', 'person': [{'firstname': 'Anna', 'middlename': None, 'lastname': 'Kodé', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1844}, {'web_url': 'https://www.nytimes.com/interactive/2023/03/24/opinion/turkey-earthquake-photos.html', 'snippet': 'A photographer revisits her homeland to document what has been lost.', 'source': 'The New York Times', 'headline': {'main': 'She Needed ‘Something, Anything, of Theirs to Go On Living.’ She Found Nothing.', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Turkey Earthquake (Feb 6, 2023)', 'rank': 1, 'major': 'N'}, {'name': 'glocations', 'value': 'Turkey', 'rank': 2, 'major': 'N'}, {'name': 'glocations', 'value': 'Adiyaman (Turkey)', 'rank': 3, 'major': 'N'}], 'pub_date': '2023-03-24T09:00:02+0000', 'byline': {'original': 'By Sabiha Cimen', 'person': [{'firstname': 'Sabiha', 'middlename': None, 'lastname': 'Cimen', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 0}, {'web_url': 'htt ...
# Retrieved 10 articles for page 9
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/interactive/2023/03/23/learning/PythonsVocabularyQuiz.html', 'snippet': 'Test your vocabulary and reading comprehension with this quiz based on the Times article “Pythons, Invasive and Hungry, Are Making Their Way North in Florida.”', 'source': 'The New York Times', 'headline': {'main': 'Vocabulary in Context: Invasive Pythons', 'kicker': 'Vocabulary', 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [], 'pub_date': '2023-03-23T09:30:00+0000', 'byline': {'original': 'Compiled by Katherine Schulten', 'person': [{'firstname': 'Katherine', 'middlename': None, 'lastname': 'Schulten', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 0}, {'web_url': 'https://www.nytimes.com/2023/03/23/sports/football/nfl-free-agents.html', 'snippet': 'Recent off-season deals also show that trades are hot, free-agent signings are not, and “bridge quarterback” is one of the greatest jobs ever.', 'source': 'The New York Times', 'headline': {'main': 'N.F.L. Teams Are Bullish on Cornerbacks and Bearish on Running Backs', 'kicker': 'trend watch', 'content_kicker': None, 'print_headline': 'Moves That Show Which Pieces Are Seen as Most Valuable', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Football', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Draft and Recruitment (Sports)', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Trades (Sports)', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Free Agents (Sports)', 'rank': 4, 'major': 'N'}, {'name': 'organizations', 'value': 'National Football League', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Barkley, Saquon (1997- )', 'rank': 6, 'major': 'N'}, {'name': 'persons', 'value': 'Bradberry, James (1993- )', 'rank': 7, 'major': 'N'}, {'name': 'persons', 'value': 'Brady, Tom', 'rank': 8, 'major': 'N'}, {'name': 'persons', 'value': 'Brissett, Jacoby (1992- )', 'rank': 9, 'major': 'N'}, {'name': 'persons', 'value': 'Cook, Dalvin (1995- )', 'rank': 10, 'major': 'N'}, {'name': 'persons', 'value': 'Dalton, Andy', 'rank': 11, 'major': 'N'}, {'name': 'persons', 'value': 'Diggs, Trevon (1997- )', 'rank': 12, 'major': 'N'}, {'name': 'persons', 'value': 'Ekeler, Austin (1995- )', 'rank': 13, 'major': 'N'}, {'name': 'persons', 'value': 'Elliott, Ezekiel (1995- )', 'rank': 14, 'major': 'N'}, {'name': 'persons', 'value': 'Gardner-Johnson, CJ', 'rank': 15, 'major': 'N'}, {'name': 'persons', 'value': 'Gilmore, Stephon (1990- )', 'rank': 16, 'major': 'N'}, {'name': 'persons', 'value': 'Heinicke, Taylor (1993- )', 'rank': 17, 'major': 'N'}, {'name': 'persons', 'value': 'Henry, Derrick', 'rank': 18, 'major': 'N'}, {'name': 'persons', 'value': 'Howard, Xavien', 'rank': 19, 'major': 'N'}, {'name': 'persons', 'value': 'Jackson, Lamar (1997- )', 'rank': 20, 'major': 'N'}, {'name': 'persons', 'value': 'Keenum, Case', 'rank': 21, 'major': 'N'}, {'name': 'persons', 'value': 'Minshew, Gardner (1996- )', 'rank': 22, 'major': 'N'}, {'name': 'persons', 'value': 'Ramsey, Jalen (1994- )', 'rank': 23, 'major': 'N'}, {'name': 'persons', 'value': 'Sanders, Miles (1997- )', 'rank': 24, 'major': 'N'}, {'name': 'persons', 'value': 'Snyder, Daniel M', 'rank': 25, 'major': 'N'}], 'pub_date': '2023-03-23T09:00:41+0000', 'byline': {'original': 'By Mike Tanier', 'person': [{'firstname': 'Mike', 'middlename': None, 'lastname': 'Tanier', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1091}, {'web_url': 'https://www.nytimes.com/2023/03/23/technology/chatbot-characterai-chatgpt-valuation.html', 'snippet': 'Founded by ex-Google employees, the Silicon Valley company is among the few start-ups poised to compete wit ...
# Retrieved 10 articles for page 10
# ...
# Retrieved 10 articles for page 16
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/15/world/europe/us-drone-russia-jet-black-sea.html', 'snippet': 'The incident was the first known physical contact between the Russian and American militaries since the war in Ukraine began.', 'source': 'The New York Times', 'headline': {'main': 'What We Know So Far About the Downed American Drone', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'glocations', 'value': 'Russia', 'rank': 1, 'major': 'N'}, {'name': 'glocations', 'value': 'Ukraine', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Russian Invasion of Ukraine (2022)', 'rank': 3, 'major': 'N'}, {'name': 'glocations', 'value': 'United States', 'rank': 4, 'major': 'N'}, {'name': 'glocations', 'value': 'Black Sea', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Drones (Pilotless Planes)', 'rank': 6, 'major': 'N'}], 'pub_date': '2023-03-15T11:25:48+0000', 'byline': {'original': 'By Matthew Mpoke Bigg', 'person': [{'firstname': 'Matthew', 'middlename': 'Mpoke', 'lastname': 'Bigg', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 643}, {'web_url': 'https://www.nytimes.com/2023/03/15/technology/siri-alexa-google-assistant-artificial-intelligence.html', 'snippet': 'The virtual assistants had more than a decade to become indispensable. But they were hampered by clunky design and miscalculations, leaving room for chatbots to rise.', 'source': 'The New York Times', 'headline': {'main': 'How Siri, Alexa and Google Assistant Lost the A.I. Race', 'kicker': None, 'content_kicker': None, 'print_headline': 'Alexa and Siri Frittered Away  Their Big Lead in the A.I. Race', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Computers and the Internet', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Artificial Intelligence', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Mobile Applications', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Speakers (Audio)', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Software', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'ChatGPT', 'rank': 6, 'major': 'N'}, {'name': 'subject', 'value': 'Voice Recognition Systems', 'rank': 7, 'major': 'N'}, {'name': 'subject', 'value': 'Smartphones', 'rank': 8, 'major': 'N'}, {'name': 'subject', 'value': 'iPhone', 'rank': 9, 'major': 'N'}, {'name': 'organizations', 'value': 'Amazon.com Inc', 'rank': 10, 'major': 'N'}, {'name': 'organizations', 'value': 'Apple Inc', 'rank': 11, 'major': 'N'}, {'name': 'organizations', 'value': 'Google Inc', 'rank': 12, 'major': 'N'}, {'name': 'organizations', 'value': 'Microsoft Corp', 'rank': 13, 'major': 'N'}, {'name': 'organizations', 'value': 'OpenAI Labs', 'rank': 14, 'major': 'N'}], 'pub_date': '2023-03-15T09:00:28+0000', 'byline': {'original': 'By Brian X. Chen, Nico Grant and Karen Weise', 'person': [{'firstname': 'Brian', 'middlename': 'X.', 'lastname': 'Chen', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}, {'firstname': 'Nico', 'middlename': None, 'lastname': 'Grant', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 2}, {'firstname': 'Karen', 'middlename': None, 'lastname': 'Weise', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 3}], 'organization': None}, 'word_count': 1383}, {'web_url': 'https://www.nytimes.com/2023/03/15/books/review/new-this-week.html', 'snippet': 'A selection of recently published books.', 'source': 'The New York Times', 'headline': {'main': 'Newly Published, From a Mozambican Emperor to Nazi Face Transplants', 'kicker': None, 'content_kicker': None, 'print_headline': 'terms with their shared trauma. Newly Published', 'name ...
# Retrieved 10 articles for page 17
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/14/us/gun-law-1791-supreme-court.html', 'snippet': 'A Supreme Court decision has forced courts to consider what gun restrictions existed two centuries ago, sending demand soaring for historians.', 'source': 'The New York Times', 'headline': {'main': 'In the Gun Law Fights of 2023, a Need for Experts on the Weapons of 1791', 'kicker': None, 'content_kicker': None, 'print_headline': 'A Sudden Need for Experts on Weapons of 1791', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'New York State Rifle & Pistol Association v Bruen (Supreme Court Decision)', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Firearms', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Gun Control', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Second Amendment (US Constitution)', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'History (Academic Subject)', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Colleges and Universities', 'rank': 6, 'major': 'N'}, {'name': 'subject', 'value': 'States (US)', 'rank': 7, 'major': 'N'}, {'name': 'subject', 'value': 'Suits and Litigation (Civil)', 'rank': 8, 'major': 'N'}, {'name': 'organizations', 'value': 'Supreme Court (US)', 'rank': 9, 'major': 'N'}, {'name': 'persons', 'value': 'Thomas, Clarence', 'rank': 10, 'major': 'N'}, {'name': 'glocations', 'value': 'United States', 'rank': 11, 'major': 'N'}, {'name': 'subject', 'value': 'audio-neutral-informative', 'rank': 12, 'major': 'N'}], 'pub_date': '2023-03-14T09:00:31+0000', 'byline': {'original': 'By Shawn Hubler', 'person': [{'firstname': 'Shawn', 'middlename': None, 'lastname': 'Hubler', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1661}, {'web_url': 'https://www.nytimes.com/2023/03/14/nyregion/housing-market-nyc-chi-osse.html', 'snippet': 'Chi Ossé called his unsuccessful search for a new home “tiring, treacherous, and competitive.” To many New Yorkers, his experience is relatable.', 'source': 'The New York Times', 'headline': {'main': 'Not Even This City Councilman Can Find an Apartment in New York City', 'kicker': None, 'content_kicker': None, 'print_headline': 'Even a City Councilman Learns It’s Hard to Find A New York Apartment', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Real Estate and Housing (Residential)', 'rank': 1, 'major': 'N'}, {'name': 'organizations', 'value': 'City Council (NYC)', 'rank': 2, 'major': 'N'}, {'name': 'glocations', 'value': 'Bedford-Stuyvesant (Brooklyn, NY)', 'rank': 3, 'major': 'N'}, {'name': 'glocations', 'value': 'Crown Heights (Brooklyn, NY)', 'rank': 4, 'major': 'N'}, {'name': 'glocations', 'value': 'New York City', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Osse, Chi', 'rank': 6, 'major': 'N'}], 'pub_date': '2023-03-14T09:00:30+0000', 'byline': {'original': 'By Mihir Zaveri', 'person': [{'firstname': 'Mihir', 'middlename': None, 'lastname': 'Zaveri', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 859}, {'web_url': 'https://www.nytimes.com/2023/03/14/books/alexa-hagerty-still-life-bones-book.html', 'snippet': 'In “Still Life With Bones,” the anthropologist Alexa Hagerty describes how she learned to see the dead with a forensic eye — and to listen to the living.', 'source': 'The New York Times', 'headline': {'main': 'In the Search for Latin America’s Disappeared, Memories and Evidence Entwine', 'kicker': None, 'content_kicker': None, 'print_headline': 'Stolen Lives: Unlocking The Stories In the Bones', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'persons', 'value': 'Hagerty, Alexa', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Forensic Sc ...
# Retrieved 10 articles for page 18
# Response Data: {'status': 'OK', 'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/03/13/arts/fbi-art-crime-team.html', 'snippet': 'A raid of the Orlando Museum of Art, in which 25 works attributed to Jean-Michel Basquiat were seized, has placed renewed spotlight on the unit.', 'source': 'The New York Times', 'headline': {'main': 'The F.B.I. Has an Art Crime Team. And These Days, It’s Busy.', 'kicker': None, 'content_kicker': None, 'print_headline': 'F.B.I. Team On the Trail Of Art Crime', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Arts and Antiquities Looting', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Museums', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Art', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Crime and Criminals', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Frauds and Swindling', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Police', 'rank': 6, 'major': 'N'}, {'name': 'organizations', 'value': 'Federal Bureau of Investigation', 'rank': 7, 'major': 'N'}], 'pub_date': '2023-03-13T15:00:12+0000', 'byline': {'original': 'By Matt Stevens', 'person': [{'firstname': 'Matt', 'middlename': None, 'lastname': 'Stevens', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1597}, {'web_url': 'https://www.nytimes.com/2023/03/13/travel/ansel-adams-photograph-sierra-nevada.html', 'snippet': 'An enigmatic photograph by America’s most famous landscape photographer led to a forensic hunt to identify exactly when and where it was taken.', 'source': 'The New York Times', 'headline': {'main': 'When the Light, Shadow and Stars Aligned: Standing Where Ansel Adams Stood', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'persons', 'value': 'ADAMS, ANSEL', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Photography', 'rank': 2, 'major': 'N'}, {'name': 'glocations', 'value': 'Kings Canyon National Park (Calif)', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'National Parks, Monuments and Seashores', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Travel and Vacations', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Hikes and Hiking', 'rank': 6, 'major': 'N'}, {'name': 'subject', 'value': 'Wilderness Areas', 'rank': 7, 'major': 'N'}, {'name': 'organizations', 'value': 'Center for Creative Photography', 'rank': 8, 'major': 'N'}, {'name': 'organizations', 'value': 'Sierra Club', 'rank': 9, 'major': 'N'}, {'name': 'subject', 'value': 'Content Type: Personal Profile', 'rank': 10, 'major': 'N'}], 'pub_date': '2023-03-13T09:00:20+0000', 'byline': {'original': 'By Kim Beil', 'person': [{'firstname': 'Kim', 'middlename': None, 'lastname': 'Beil', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 3672}, {'web_url': 'https://www.nytimes.com/2023/03/13/books/review/poverty-by-america-matthew-desmond.html', 'snippet': 'The new book by the sociologist and author of “Evicted” examines the persistence of want in the wealthy United States, finding that keeping some citizens poor serves the interests of many.', 'source': 'The New York Times', 'headline': {'main': 'In Matthew Desmond’s ‘Poverty, by America,’ the Culprit Is Us', 'kicker': 'Nonfiction', 'content_kicker': None, 'print_headline': 'Down and Out in Paradise', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Books and Literature', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Poverty', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Desmond, Matthew S (1980- )', 'rank': 3, 'major': 'N'}, {'name': 'glocations', 'value': 'United States', 'rank': 4, 'major': 'N'}, {'name': 'creative_works', 'value': 'Po ...
# Retrieved 10 articles for page 19
# Total articles retrieved: 200

# %%
for review in review_list:
    url = review.get("web_url", "")
    if url:
        try:
            response = requests.get(url)

            if response.status_code ==200:
                if 'application/json' in response.headers.get('Content-Type', ''):
                    try:
                        review_data = response.json()
                        all_results.extend(review_data)
        # Print the page that was just retrieved
                        print("Retrieved data for page:", url)
                    except ValueError:
                        print("Response content is not valid JSON:", url)
                else:
                    print("Response content is not JSON:", url)
            else:
                print(f"Failed to retrieve data for review:", url)
        except requests.exceptions.RequestException as e:
            print(f"Error occurred while fetching data for review (url): (e)")
    else:
        print("No url found for reveiw.")
# Out:
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/31/sports/ncaabasketball/locker-room-celebrations-water-pour.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/us/minneapolis-police-reform-agreement.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/briefing/donald-trump-arraignment-russia-recruitment.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/technology/sam-altman-open-ai-chatgpt.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/opinion/ai-pause.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/technology/google-pichai-ai.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/science/astrolab-moon-rover-spacex.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/technology/facial-recognition-false-arrests.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/sports/soccer/liverpool-manchester-city.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/crosswords/the-long-way-home-crossword-puzzle.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/realestate/scotland-golf-archerfield-house.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/realestate/design-golf-homes.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/realestate/first-time-home-buyer-retirement.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/travel/budget-family-travel.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/arts/television/31yellowjackets-recap-season-2-episode-2.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/31/t-magazine/alex-newell-shucked.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/31/realestate/home-buying-real-estate-quiz.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/business/media/trump-indictment-social-media-conspiracy.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/crosswords/variety-encyclopedia-search.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/nyregion/trump-mar-a-lago.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/us/las-vegas-shooting-gunman.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/books/review/9-new-books-we-recommend-this-week.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/us/politics/biden-irs-overhaul-taxes.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/30/science/einstein-tilings-burst.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/style/ryder-ripps-bored-apes-kanye.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/world/canada/inquiry-police-deadliest-shooting.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/well/move/running-shoes.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/learning/our-6th-annual-student-podcast-contest.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/world/asia/sailboat-whale-rescue-pacific.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/world/americas/dona-angela-youtube-cooking-mexico.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/movies/kill-boksoon-review.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/world/europe/ukraine-satellite-darkness.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/business/media/publishers-chatbots-search-engines.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/business/economy/remote-work-measure-surveys.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/30/realestate/manhattan-studio-apartment-east-side.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/30/briefing/nuclear-plant-ukraine-europe.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/crosswords/daily-puzzle-2023-03-30.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/us/lake-mead-human-remains.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/world/europe/amsterdam-uk-tourists-stay-away.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/arts/television/extrapolations-climate-change.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/nyregion/nyc-suburbs-homes-hochul.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/realestate/wallkill-ny-homes-hudson-valley.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/technology/personaltech/ai-chatgpt-google-bard-assistant.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/theater/tashnuva-anan-public-obscenities.html
# Failed to retrieve data for review: https://www.nytimes.com/article/nashville-school-shooting.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/opinion/housing-future-new-york-city.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/opinion/red-blue-tight-loose-state.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/technology/activision-netease-china-breakup.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/nyregion/james-ray-murder-trial-montclair.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/travel/film-and-tv-tours-james-bond.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/opinion/how-to-accept-death.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/29/travel/adult-resorts-family-kids.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/28/us/politics/biden-economy.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/28/world/europe/russia-repression-children.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/28/us/politics/artificial-intelligence-2024-campaigns.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/28/sports/football/lamar-jackson-aaron-rodgers-trade.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/28/world/europe/moskalyov-verdict-russia-daughter-custody.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/28/business/dealbook/silicon-valley-bank.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/28/books/review/the-great-reclamation-rachel-heng.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/28/business/economy/jobs-ai-artificial-intelligence-chatgpt.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/28/style/big-shoulders-trend.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/28/magazine/quarantine-hotel-vacation.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/27/technology/lyft-founders-resign.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/27/opinion/ai-chatgpt-chatbots.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/27/nyregion/nj-attorney-general-paterson-police.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/27/opinion/problem-college-rankings.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/27/opinion/how-build-your-own-college-rankings-was-built.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/26/sports/ncaabasketball/march-madness-sunday-women.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/26/sports/ncaabasketball/march-madness-sunday-men.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/26/briefing/asia-weapons-putin-belarus-israel-netanyahu.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/26/us/violent-storms-leave-behind-scenes-of-devastation-and-heartbreak.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/26/technology/apple-augmented-reality-dissent.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/26/briefing/turkey-earthquake.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/26/business/the-week-in-business-tiktok-in-the-hot-seat.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/26/fashion/watches-eoniq-hong-kong.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/26/business/esther-perel-couples-therapy.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/25/us/how-to-help-mississippi-tornadoes.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/25/us/politics/trump-2024-rally-waco-texas.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/25/us/afroman-videos-sued.html
# Failed to retrieve data for review: https://www.nytimes.com/article/how-the-times-covers-extreme-weather.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/25/us/tornado-mississippi-storms-dead.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/us/fire-chocolate-factory-west-reading.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/us/politics/trump-mark-meadows-executive-privilege-jan-6.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/briefing/us-arms-production-india-parliament.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/movies/five-action-movies-to-stream-now.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/arts/design/alberto-ibarguen-retiring-knight-foundation.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/world/europe/scotland-forced-adoption.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/climate/climate-action-handbook.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/us/severe-weather-tornado-south-forecast.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/nyregion/hart-island-cemetery-park.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/us/politics/donald-trump-waco-branch-davidians.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/24/realestate/mushroom-home-decor.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/24/opinion/turkey-earthquake-photos.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/us/denver-school-shooting-safety-plan.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/world/europe/olympics-ban-russia-belarus-track.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/us/politics/trump-documents-special-counsel-grand-jury.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/us/politics/trump-investigations-justice-department-garland-bragg.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/t-magazine/harry-nuriev-apartment-design.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/t-magazine/weyes-blood-j-hannah-necklace.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/movies/the-lost-king-review.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/23/learning/PythonsVocabularyQuiz.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/sports/football/nfl-free-agents.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/technology/chatbot-characterai-chatgpt-valuation.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/books/review/all-the-knowledge-in-the-world-simon-garfield.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/sports/baseball/triston-mckenzie-logan-gilbert.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/23/realestate/home-thousand-oaks-southern-california.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/23/nyregion/pickleball-wollman-rink.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/briefing/fed-interest-rates-daily-show-trevor-noah.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/us/denver-school-shooting.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/us/politics/trump-lawyer-classified-documents-investigation.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/well/family/ai-chatgpt-parents-children.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/business/dealbook/credit-suisses-investment-bank.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/briefing/fed-banking-interest-rates.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/arts/design/artists-stanislava-pinchuk-jakkai-siributr.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/arts/design/hong-kong-museum-m-plus.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/business/media/ai-chatbots-right-wing-conservative.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/magazine/maze-tourism.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/nyregion/michael-cohen-donald-trump-indictment.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/arts/design/hong-kong-galleries-new.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/22/nyregion/green-wood-cemetery-burial-records.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/21/briefing/congress-insurance-deposit-limit-los-angeles-schools.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/21/technology/google-bard-guide-test.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/21/arts/music/virginia-zeani-dead.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/21/us/abigail-zwerner-virginia-teacher-shooting.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/21/theater/shucked-musical-broadway.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/21/podcasts/ezra-klein-podcast-transcript-kelsey-piper.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/21/technology/google-bard-chatbot.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/21/us/politics/trump-2024-campaign-indictment.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/21/upshot/trump-indictment-polling.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/20/briefing/xi-putin-china-russia-asia.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/20/crosswords/spelling-bee-diary.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/20/world/asia/india-punjab-internet-shutdown-amritpal-singh.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/20/world/europe/wwii-pilot-remains-identified.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/20/travel/penang-malaysia-george-town.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/20/magazine/women-friendships-travel-morocco.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/20/magazine/colin-koopman-interview.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/20/world/middleeast/iraq-war-anniversary-youth.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/20/us/politics/trump-indictment-republicans.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/20/nyregion/love-new-york-campaign.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/19/us/politics/trump-investigations.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/19/opinion/pets-dogs-love.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/19/books/review/meganets-david-auerbach-review.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/19/us/phoenix-businesses-homelessness.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/18/us/kentucky-university-wrestler-settlement.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/18/us/politics/jimmy-carter-october-surprise-iran-hostages.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/18/realestate/failure-to-pay-rent.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/18/us/politics/trump-indictment-arrest-protests.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/18/business/silicon-valley-bank-collapse.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/18/world/middleeast/iraq-war-photos-us-military.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/17/opinion/jay-clayton-gary-cohn-regulation-silicon-valley-bank.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/17/us/politics/trump-lawyer-testify-documents.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/17/science/animal-cafes-japan-endangered.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/17/books/review/new-paperbacks.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/17/sports/soccer/ajax-feyenoord-jurrien-timber.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/17/movies/science-fiction-movies-streaming.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/17/world/asia/thailand-radioactive-canister-lost.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/17/business/401k-ira-balances-retirement.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/16/technology/microsoft-google-ai-tools-businesses.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/16/us/hikers-dead-buckskin-gulch-utah.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/16/us/how-californias-elephant-seals-made-a-remarkable-recovery.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/16/world/asia/china-baidu-chatgpt-ernie.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/16/movies/the-magicians-elephant-review.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/16/travel/chatgpt-artificial-intelligence-travel-vacation.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/15/crosswords/daily-puzzle-2023-03-16.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/15/sports/ncaabasketball/bracket-help-ncaa-ai.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/15/sports/ncaabasketball/alabama-shooting.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/15/podcasts/modern-love-perfect-partner.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/15/technology/gpt-4-artificial-intelligence-openai.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/15/magazine/cfcs-inventor.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/15/climate/seaweed-plastic-climate-change.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/15/world/europe/us-drone-russia-jet-black-sea.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/15/technology/siri-alexa-google-assistant-artificial-intelligence.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/15/books/review/new-this-week.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/15/opinion/european-parliament-qatargate.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/15/nyregion/code-breaker-world-war-2.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/14/us/politics/ron-desantis-ukraine-republicans.html
# Response content is not JSON: https://www.nytimes.com/interactive/2023/03/14/dining/kid-friendly-recipes.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/14/us/politics/boris-epshteyn-trump-lawyer.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/14/world/africa/cyclone-freddy-malawi-mudslides-flooding.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/14/technology/openai-gpt4-chatgpt.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/14/us/gun-law-1791-supreme-court.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/14/nyregion/housing-market-nyc-chi-osse.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/14/books/alexa-hagerty-still-life-bones-book.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/14/special-series/protopia-movement.html
# Response content is not JSON: https://www.nytimes.com/video/world/africa/100000008811802/cyclone-freddy-africa-dead.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/13/crosswords/daily-puzzle-2023-03-14.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/13/business/masatoshi-ito-dead.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/13/your-money/fdic-banks-svb.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/13/nyregion/nj-police-shooting-najee-seabrooks.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/13/business/media/lifehacker-ziff-davis.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/13/arts/fbi-art-crime-team.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/13/travel/ansel-adams-photograph-sierra-nevada.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/13/books/review/poverty-by-america-matthew-desmond.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/13/books/kenzaburo-oe-dead.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/13/business/ai-hiring-jobs.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/12/us/radioactive-camera-missing-houston.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/12/climate/silicon-valley-bank-climate.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/12/us/san-diego-drownings.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/12/dining/what-to-cook-this-week.html
# Failed to retrieve data for review: https://www.nytimes.com/2023/03/12/fashion/jewelry-tucson-gem-shows-arizona.html

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

print(json.dumps(response_data, indent=4))
# Out:
# {
#     "status": "OK",
#     "copyright": "Copyright (c) 2024 The New York Times Company. All Rights Reserved.",
#     "response": {
#         "docs": [
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/13/arts/fbi-art-crime-team.html",
#                 "snippet": "A raid of the Orlando Museum of Art, in which 25 works attributed to Jean-Michel Basquiat were seized, has placed renewed spotlight on the unit.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "The F.B.I. Has an Art Crime Team. And These Days, It\u2019s Busy.",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "F.B.I. Team On the Trail Of Art Crime",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Arts and Antiquities Looting",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Museums",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Art",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Crime and Criminals",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Frauds and Swindling",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Police",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Federal Bureau of Investigation",
#                         "rank": 7,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T15:00:12+0000",
#                 "byline": {
#                     "original": "By Matt Stevens",
#                     "person": [
#                         {
#                             "firstname": "Matt",
#                             "middlename": null,
#                             "lastname": "Stevens",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 1597
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/13/travel/ansel-adams-photograph-sierra-nevada.html",
#                 "snippet": "An enigmatic photograph by America\u2019s most famous landscape photographer led to a forensic hunt to identify exactly when and where it was taken.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "When the Light, Shadow and Stars Aligned: Standing Where Ansel Adams Stood",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": null,
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "persons",
#                         "value": "ADAMS, ANSEL",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Photography",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Kings Canyon National Park (Calif)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "National Parks, Monuments and Seashores",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Travel and Vacations",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Hikes and Hiking",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Wilderness Areas",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Center for Creative Photography",
#                         "rank": 8,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Sierra Club",
#                         "rank": 9,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Content Type: Personal Profile",
#                         "rank": 10,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T09:00:20+0000",
#                 "byline": {
#                     "original": "By Kim Beil",
#                     "person": [
#                         {
#                             "firstname": "Kim",
#                             "middlename": null,
#                             "lastname": "Beil",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 3672
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/13/books/review/poverty-by-america-matthew-desmond.html",
#                 "snippet": "The new book by the sociologist and author of \u201cEvicted\u201d examines the persistence of want in the wealthy United States, finding that keeping some citizens poor serves the interests of many.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "In Matthew Desmond\u2019s \u2018Poverty, by America,\u2019 the Culprit Is Us",
#                     "kicker": "Nonfiction",
#                     "content_kicker": null,
#                     "print_headline": "Down and Out in Paradise",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Books and Literature",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Poverty",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Desmond, Matthew S (1980- )",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "United States",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Poverty, by America (Book)",
#                         "rank": 5,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T09:00:08+0000",
#                 "byline": {
#                     "original": "By Alec MacGillis",
#                     "person": [
#                         {
#                             "firstname": "Alec",
#                             "middlename": null,
#                             "lastname": "MacGillis",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 1415
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/13/books/kenzaburo-oe-dead.html",
#                 "snippet": "With his powerful novels and essays, Mr. Oe tried to ensure that Japan learned the lessons of its 20th-century militarism.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "Kenzaburo Oe, Nobel Laureate and Critic of Postwar Japan, Dies at 88",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Kenzaburo Oe, Nobel-Winning Critic of Postwar Japan, Dies at 88",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "persons",
#                         "value": "Oe, Kenzaburo",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Deaths (Obituaries)",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Books and Literature",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Writing and Writers",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Nobel Prizes",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Politics and Government",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Japan",
#                         "rank": 7,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T07:26:42+0000",
#                 "byline": {
#                     "original": "By Daniel Lewis",
#                     "person": [
#                         {
#                             "firstname": "Daniel",
#                             "middlename": null,
#                             "lastname": "Lewis",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 1803
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/13/business/ai-hiring-jobs.html",
#                 "snippet": "Using A.I. tools in hiring is one of the most promising and contentious uses of the technology. The experience of a company called Eightfold AI shows the challenges.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "An A.I. Start-Up Boomed, but Now It Faces a Slowing Economy and New Rules",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "The Business of A.I.-Based Hiring Is No Sure Thing",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Artificial Intelligence",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Eightfold AI",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Computers and the Internet",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Hiring and Promotion",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Start-ups",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Micron Technology Inc",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Garg, Ashutosh",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Kacholia, Varun",
#                         "rank": 8,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T07:00:09+0000",
#                 "byline": {
#                     "original": "By Steve Lohr",
#                     "person": [
#                         {
#                             "firstname": "Steve",
#                             "middlename": null,
#                             "lastname": "Lohr",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 1358
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/12/us/radioactive-camera-missing-houston.html",
#                 "snippet": "While multiple layers of protection surround the radioactive material, and levels of radiation outside the camera are not dangerous, it should be handled with care, state officials said.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "A Camera Containing Radioactive Material Is Missing in the Houston Area",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": null,
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Radiation",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Cameras",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Houston (Tex)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Statewide Maintenance Co",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Lost and Found Property",
#                         "rank": 5,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T00:08:01+0000",
#                 "byline": {
#                     "original": "By April Rubin",
#                     "person": [
#                         {
#                             "firstname": "April",
#                             "middlename": null,
#                             "lastname": "Rubin",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 434
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/12/climate/silicon-valley-bank-climate.html",
#                 "snippet": "The bank had relationships with more than 1,500 companies working on technologies aimed at curbing global warming.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "Silicon Valley Bank Collapse Threatens Climate Start-Ups",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Bank\u2019s Collapse Leaves   Climate Start-Ups at Risk",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Global Warming",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Start-ups",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Inflation Reduction Act of 2022",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Banking and Financial Institutions",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Greenhouse Gas Emissions",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Silicon Valley Bank",
#                         "rank": 6,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-12T21:39:06+0000",
#                 "byline": {
#                     "original": "By David Gelles",
#                     "person": [
#                         {
#                             "firstname": "David",
#                             "middlename": null,
#                             "lastname": "Gelles",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 1026
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/12/us/san-diego-drownings.html",
#                 "snippet": "Searchers recovered bodies, life jackets and fuel barrels in what one official described as \u201cone of the worst maritime smuggling tragedies\u201d in recent years.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "At Least 8 Dead After Boats Capsize in Human Smuggling Attempt in San Diego",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": null,
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Maritime Accidents and Safety",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Smuggling",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Illegal Immigration",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Deaths (Fatalities)",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Drownings",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Black's Beach (California)",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "San Diego (Calif)",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Pacific Ocean",
#                         "rank": 8,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-12T17:34:47+0000",
#                 "byline": {
#                     "original": "By Sara Clemence and Emily Schmall",
#                     "person": [
#                         {
#                             "firstname": "Sara",
#                             "middlename": null,
#                             "lastname": "Clemence",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         },
#                         {
#                             "firstname": "Emily",
#                             "middlename": null,
#                             "lastname": "Schmall",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 2
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 757
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/12/dining/what-to-cook-this-week.html",
#                 "snippet": "Ricotta pasta alla vodka, cauliflower shawarma and more recipes.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "What to Cook This Week",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": null,
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Cooking and Cookbooks",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Content Type: Service",
#                         "rank": 2,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-12T15:00:03+0000",
#                 "byline": {
#                     "original": "By Sam Sifton",
#                     "person": [
#                         {
#                             "firstname": "Sam",
#                             "middlename": null,
#                             "lastname": "Sifton",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 666
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/12/fashion/jewelry-tucson-gem-shows-arizona.html",
#                 "snippet": "From inexpensive amazonite to wildly expensive faceted zircon, the stones at the annual gem shows in Tucson draw jewelers from around the world.",
#                 "source": "International New York Times",
#                 "headline": {
#                     "main": "Brilliance in the Sonoran Desert",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Brilliance in the desert",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Jewels and Jewelry",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Conventions, Fairs and Trade Shows",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "American Gem Trade Assn",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Godfrey, Lauren Harwell",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Webster, Stephen",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Tucson (Ariz)",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "your-feed-fashion",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Photography",
#                         "rank": 8,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-12T09:12:12+0000",
#                 "byline": {
#                     "original": "By Victoria Gomelsky and Rebecca Noble",
#                     "person": [
#                         {
#                             "firstname": "Victoria",
#                             "middlename": null,
#                             "lastname": "Gomelsky",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         },
#                         {
#                             "firstname": "Rebecca",
#                             "middlename": null,
#                             "lastname": "Noble",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 2
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 842
#             }
#         ],
#         "meta": {
#             "hits": 41595,
#             "offset": 190,
#             "time": 53
#         }
#     }
# }

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()

reviews_list_df = pd.json_normalize(response_data['response']['docs'])
reviews_list_df

print(json.dumps(response_data, indent=4))
# Out:
# {
#     "status": "OK",
#     "copyright": "Copyright (c) 2024 The New York Times Company. All Rights Reserved.",
#     "response": {
#         "docs": [
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/13/arts/fbi-art-crime-team.html",
#                 "snippet": "A raid of the Orlando Museum of Art, in which 25 works attributed to Jean-Michel Basquiat were seized, has placed renewed spotlight on the unit.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "The F.B.I. Has an Art Crime Team. And These Days, It\u2019s Busy.",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "F.B.I. Team On the Trail Of Art Crime",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Arts and Antiquities Looting",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Museums",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Art",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Crime and Criminals",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Frauds and Swindling",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Police",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Federal Bureau of Investigation",
#                         "rank": 7,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T15:00:12+0000",
#                 "byline": {
#                     "original": "By Matt Stevens",
#                     "person": [
#                         {
#                             "firstname": "Matt",
#                             "middlename": null,
#                             "lastname": "Stevens",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 1597
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/13/travel/ansel-adams-photograph-sierra-nevada.html",
#                 "snippet": "An enigmatic photograph by America\u2019s most famous landscape photographer led to a forensic hunt to identify exactly when and where it was taken.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "When the Light, Shadow and Stars Aligned: Standing Where Ansel Adams Stood",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": null,
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "persons",
#                         "value": "ADAMS, ANSEL",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Photography",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Kings Canyon National Park (Calif)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "National Parks, Monuments and Seashores",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Travel and Vacations",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Hikes and Hiking",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Wilderness Areas",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Center for Creative Photography",
#                         "rank": 8,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Sierra Club",
#                         "rank": 9,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Content Type: Personal Profile",
#                         "rank": 10,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T09:00:20+0000",
#                 "byline": {
#                     "original": "By Kim Beil",
#                     "person": [
#                         {
#                             "firstname": "Kim",
#                             "middlename": null,
#                             "lastname": "Beil",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 3672
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/13/books/review/poverty-by-america-matthew-desmond.html",
#                 "snippet": "The new book by the sociologist and author of \u201cEvicted\u201d examines the persistence of want in the wealthy United States, finding that keeping some citizens poor serves the interests of many.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "In Matthew Desmond\u2019s \u2018Poverty, by America,\u2019 the Culprit Is Us",
#                     "kicker": "Nonfiction",
#                     "content_kicker": null,
#                     "print_headline": "Down and Out in Paradise",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Books and Literature",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Poverty",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Desmond, Matthew S (1980- )",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "United States",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "creative_works",
#                         "value": "Poverty, by America (Book)",
#                         "rank": 5,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T09:00:08+0000",
#                 "byline": {
#                     "original": "By Alec MacGillis",
#                     "person": [
#                         {
#                             "firstname": "Alec",
#                             "middlename": null,
#                             "lastname": "MacGillis",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 1415
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/13/books/kenzaburo-oe-dead.html",
#                 "snippet": "With his powerful novels and essays, Mr. Oe tried to ensure that Japan learned the lessons of its 20th-century militarism.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "Kenzaburo Oe, Nobel Laureate and Critic of Postwar Japan, Dies at 88",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Kenzaburo Oe, Nobel-Winning Critic of Postwar Japan, Dies at 88",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "persons",
#                         "value": "Oe, Kenzaburo",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Deaths (Obituaries)",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Books and Literature",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Writing and Writers",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Nobel Prizes",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Politics and Government",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Japan",
#                         "rank": 7,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T07:26:42+0000",
#                 "byline": {
#                     "original": "By Daniel Lewis",
#                     "person": [
#                         {
#                             "firstname": "Daniel",
#                             "middlename": null,
#                             "lastname": "Lewis",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 1803
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/13/business/ai-hiring-jobs.html",
#                 "snippet": "Using A.I. tools in hiring is one of the most promising and contentious uses of the technology. The experience of a company called Eightfold AI shows the challenges.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "An A.I. Start-Up Boomed, but Now It Faces a Slowing Economy and New Rules",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "The Business of A.I.-Based Hiring Is No Sure Thing",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Artificial Intelligence",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Eightfold AI",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Computers and the Internet",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Hiring and Promotion",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Start-ups",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Micron Technology Inc",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Garg, Ashutosh",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Kacholia, Varun",
#                         "rank": 8,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T07:00:09+0000",
#                 "byline": {
#                     "original": "By Steve Lohr",
#                     "person": [
#                         {
#                             "firstname": "Steve",
#                             "middlename": null,
#                             "lastname": "Lohr",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 1358
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/12/us/radioactive-camera-missing-houston.html",
#                 "snippet": "While multiple layers of protection surround the radioactive material, and levels of radiation outside the camera are not dangerous, it should be handled with care, state officials said.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "A Camera Containing Radioactive Material Is Missing in the Houston Area",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": null,
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Radiation",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Cameras",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Houston (Tex)",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Statewide Maintenance Co",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Lost and Found Property",
#                         "rank": 5,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-13T00:08:01+0000",
#                 "byline": {
#                     "original": "By April Rubin",
#                     "person": [
#                         {
#                             "firstname": "April",
#                             "middlename": null,
#                             "lastname": "Rubin",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 434
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/12/climate/silicon-valley-bank-climate.html",
#                 "snippet": "The bank had relationships with more than 1,500 companies working on technologies aimed at curbing global warming.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "Silicon Valley Bank Collapse Threatens Climate Start-Ups",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Bank\u2019s Collapse Leaves   Climate Start-Ups at Risk",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Global Warming",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Start-ups",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Inflation Reduction Act of 2022",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Banking and Financial Institutions",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Greenhouse Gas Emissions",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "Silicon Valley Bank",
#                         "rank": 6,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-12T21:39:06+0000",
#                 "byline": {
#                     "original": "By David Gelles",
#                     "person": [
#                         {
#                             "firstname": "David",
#                             "middlename": null,
#                             "lastname": "Gelles",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 1026
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/12/us/san-diego-drownings.html",
#                 "snippet": "Searchers recovered bodies, life jackets and fuel barrels in what one official described as \u201cone of the worst maritime smuggling tragedies\u201d in recent years.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "At Least 8 Dead After Boats Capsize in Human Smuggling Attempt in San Diego",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": null,
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Maritime Accidents and Safety",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Smuggling",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Illegal Immigration",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Deaths (Fatalities)",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Drownings",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Black's Beach (California)",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "San Diego (Calif)",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Pacific Ocean",
#                         "rank": 8,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-12T17:34:47+0000",
#                 "byline": {
#                     "original": "By Sara Clemence and Emily Schmall",
#                     "person": [
#                         {
#                             "firstname": "Sara",
#                             "middlename": null,
#                             "lastname": "Clemence",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         },
#                         {
#                             "firstname": "Emily",
#                             "middlename": null,
#                             "lastname": "Schmall",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 2
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 757
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/12/dining/what-to-cook-this-week.html",
#                 "snippet": "Ricotta pasta alla vodka, cauliflower shawarma and more recipes.",
#                 "source": "The New York Times",
#                 "headline": {
#                     "main": "What to Cook This Week",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": null,
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Cooking and Cookbooks",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Content Type: Service",
#                         "rank": 2,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-12T15:00:03+0000",
#                 "byline": {
#                     "original": "By Sam Sifton",
#                     "person": [
#                         {
#                             "firstname": "Sam",
#                             "middlename": null,
#                             "lastname": "Sifton",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 666
#             },
#             {
#                 "web_url": "https://www.nytimes.com/2023/03/12/fashion/jewelry-tucson-gem-shows-arizona.html",
#                 "snippet": "From inexpensive amazonite to wildly expensive faceted zircon, the stones at the annual gem shows in Tucson draw jewelers from around the world.",
#                 "source": "International New York Times",
#                 "headline": {
#                     "main": "Brilliance in the Sonoran Desert",
#                     "kicker": null,
#                     "content_kicker": null,
#                     "print_headline": "Brilliance in the desert",
#                     "name": null,
#                     "seo": null,
#                     "sub": null
#                 },
#                 "keywords": [
#                     {
#                         "name": "subject",
#                         "value": "Jewels and Jewelry",
#                         "rank": 1,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Conventions, Fairs and Trade Shows",
#                         "rank": 2,
#                         "major": "N"
#                     },
#                     {
#                         "name": "organizations",
#                         "value": "American Gem Trade Assn",
#                         "rank": 3,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Godfrey, Lauren Harwell",
#                         "rank": 4,
#                         "major": "N"
#                     },
#                     {
#                         "name": "persons",
#                         "value": "Webster, Stephen",
#                         "rank": 5,
#                         "major": "N"
#                     },
#                     {
#                         "name": "glocations",
#                         "value": "Tucson (Ariz)",
#                         "rank": 6,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "your-feed-fashion",
#                         "rank": 7,
#                         "major": "N"
#                     },
#                     {
#                         "name": "subject",
#                         "value": "Photography",
#                         "rank": 8,
#                         "major": "N"
#                     }
#                 ],
#                 "pub_date": "2023-03-12T09:12:12+0000",
#                 "byline": {
#                     "original": "By Victoria Gomelsky and Rebecca Noble",
#                     "person": [
#                         {
#                             "firstname": "Victoria",
#                             "middlename": null,
#                             "lastname": "Gomelsky",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 1
#                         },
#                         {
#                             "firstname": "Rebecca",
#                             "middlename": null,
#                             "lastname": "Noble",
#                             "qualifier": null,
#                             "title": null,
#                             "role": "reported",
#                             "organization": "",
#                             "rank": 2
#                         }
#                     ],
#                     "organization": null
#                 },
#                 "word_count": 842
#             }
#         ],
#         "meta": {
#             "hits": 41595,
#             "offset": 190,
#             "time": 53
#         }
#     }
# }

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
if 'headline.main' in reviews_list_df.columns:

    def extract_title(text):
        start_index = text.find("\u2018")
        end_index = text.find("\u2019 Review")
        if start_index != -1 and end_index != -1:
            return text [start_index + 1:end_index]
        else:
            return None

    reviews_list_df['title'] = reviews_list_df['headline.main'].apply(extract_title)
else:
    print("Column 'headline.main' does not exist in the DataFrame.")
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early

# %%
# Extract 'name' and 'value' from items in "keywords" column
import ast

def extract_keywords(keyword_list):
    try:
   
        keyword_list = ast.literal_eval(keyword_list)
        extracted_keywords = ""
        for item in keyword_list:
            if 'name' in item:
                
        # Extract 'name' and 'value'
                extracted_keywords += f"{item['name']},"  
        # Append the keyword item to the extracted_keywords list
        
        return extracted_keywords.strip(",")
    except (SyntaxError, ValueError):
        return "Error extracting keywords"

# Fix the "keywords" column by converting cells from a list to a string
reviews_list_df['keywords'] = reviews_list_df['keywords'].apply(lambda x:extract_keywords(x))

print(reviews_list_df.head())
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/03/13/arts/fbi-ar...
# 1  https://www.nytimes.com/2023/03/13/travel/anse...
# 2  https://www.nytimes.com/2023/03/13/books/revie...
# 3  https://www.nytimes.com/2023/03/13/books/kenza...
# 4  https://www.nytimes.com/2023/03/13/business/ai...
#
#                                              snippet              source  \
# 0  A raid of the Orlando Museum of Art, in which ...  The New York Times
# 1  An enigmatic photograph by America’s most famo...  The New York Times
# 2  The new book by the sociologist and author of ...  The New York Times
# 3  With his powerful novels and essays, Mr. Oe tr...  The New York Times
# 4  Using A.I. tools in hiring is one of the most ...  The New York Times
#
#                     keywords                  pub_date  word_count  \
# 0  Error extracting keywords  2023-03-13T15:00:12+0000        1597
# 1  Error extracting keywords  2023-03-13T09:00:20+0000        3672
# 2  Error extracting keywords  2023-03-13T09:00:08+0000        1415
# 3  Error extracting keywords  2023-03-13T07:26:42+0000        1803
# 4  Error extracting keywords  2023-03-13T07:00:09+0000        1358
#
#                                        headline.main headline.kicker  \
# 0  The F.B.I. Has an Art Crime Team. And These Da...            None
# 1  When the Light, Shadow and Stars Aligned: Stan...            None
# 2  In Matthew Desmond’s ‘Poverty, by America,’ th...      Nonfiction
# 3  Kenzaburo Oe, Nobel Laureate and Critic of Pos...            None
# 4  An A.I. Start-Up Boomed, but Now It Faces a Sl...            None
#
#   headline.content_kicker                            headline.print_headline  \
# 0                    None              F.B.I. Team On the Trail Of Art Crime
# 1                    None                                               None
# 2                    None                           Down and Out in Paradise
# 3                    None  Kenzaburo Oe, Nobel-Winning Critic of Postwar ...
# 4                    None  The Business of A.I.-Based Hiring Is No Sure T...
#
#   headline.name headline.seo headline.sub    byline.original  \
# 0          None         None         None    By Matt Stevens
# 1          None         None         None        By Kim Beil
# 2          None         None         None  By Alec MacGillis
# 3          None         None         None    By Daniel Lewis
# 4          None         None         None      By Steve Lohr
#
#                                        byline.person byline.organization title
# 0  [{'firstname': 'Matt', 'middlename': None, 'la...                None  None
# 1  [{'firstname': 'Kim', 'middlename': None, 'las...                None  None
# 2  [{'firstname': 'Alec', 'middlename': None, 'la...                None  None
# 3  [{'firstname': 'Daniel', 'middlename': None, '...                None  None
# 4  [{'firstname': 'Steve', 'middlename': None, 'l...                None  None

# %%
# Create a list from the "title" column using to_list()

title_list = reviews_list_df['title'].to_list()
# These titles will be used in the query for The Movie Database
print(title_list)
# Out:
# [None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
results_list = []
movie_ids = ["movie_id", "genres.", "name"]


# Create a request counter to sleep the requests after a multiple
# of 50 requests
import requests
import time

request_counter = 0
request_limit = 50


# Loop through the titles
for movie_id in movie_ids:
    # Check if we need to sleep before making a request
    if request_counter > 0 and request_counter % request_limit == 0:
        print("Pausing requests...")
        time.sleep(5)  



    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    movie_details_url = f"https://api.themoviedb.org/3/movie/{movie_id}"
    response_details = requests.get(movie_details_url)

    # Include a try clause to search for the full movie details.
    try:
        if response_details.status_code == 200:
        
    # Use the except clause to print out a statement if a movie
    # is not found.

        # Get movie id
                genres = [genre['name'] for genre in response_details.json()['genres']]


        # Make a request for a the full movie details
                spoken_languages = [lang['english_name'] for lang in response_details.json()['spoken_languages']]


        # Execute "GET" request with url
                response = requests.get(UnicodeTranslateError)

        
        # Extract the genre names into a list
                genres = [genre['name'] for genre in response_details.json()['genres']]

        # Extract the spoken_languages' English name into a list
                spoken_languages = [lang['english_name'] for lang in response_details.json()['spoken_languages']]


        # Extract the production_countries' name into a list

                production_countries = [country['name'] for country in response_details.json()['production_countries']]


        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
                results_list.append({
                        'movie_id': movie_id,
                        'genres': genres,
                        'spoken_languages': spoken_languages,
                        'production_countries': production_countries
                })
        
        # Print out the title that was found
                print(f"Title found: {movie_id}")
        else:
                print(f"Movie ID not found: {movie_id}")
    except KeyError:
        print(f"Error occurred while processing movie ID: {movie_id}. Data not found.")
print(results_list)
# Out:
# Movie ID not found: movie_id
# Movie ID not found: genres.
# Movie ID not found: name
# []

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

# %%
# Convert the results to a DataFrame

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index

# %%
# Export data to CSV without the index
